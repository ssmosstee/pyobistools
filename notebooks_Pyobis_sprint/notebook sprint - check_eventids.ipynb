# %%
import pandas as pd
import numpy as np
from ckanapi import RemoteCKAN
NaN = np.nan
from pyobistools.validation.check_eventids import check_eventids, check_extension_eventids
import plotly.express as px
import requests
pd.set_option('max_colwidth', None)

# %% [markdown]
# ### Info about this notebook series
#
# This series of notebook is meant to serve as an educational tool to learn how to use the PyObis biodiversity data validation package: + https://github.com/cioos-siooc/pyobistools
#
# Command to install PyObis (currently not hosted on Pypi)
# + pip install git+https://github.com/cioos-siooc/pyobistools@main#egg=pyobistools
#
# Darwin Core documentation:
# + https://dwc.tdwg.org/
#
# Darwin Core file types required fields:
# + https://ioos.github.io/bio_mobilization_workshop/01-introduction/index.html
# + https://ioos.github.io/bio_mobilization_workshop/04-create-schema/index.html

# %% [markdown]
# ### Notebook to test Pyobis' functions 'check_eventids' and 'check_extension_eventids'
#
# ##### Function 'check_eventids' description
# The 'check_eventids' function is used with one file of either Darwin Core file types 'event_core' or 'occurrence_core', to report:
#     + the absence of the fields 'eventid' and 'parenteventid'
#     + duplicates values in 'event_ids'
#     + if all 'parentEventIDs' have corresponding 'eventid' in a given file
#
# ##### Function 'check_eventids' arguments
# + data: Dataframe of the data to evaluate
#
#
# ##### Function 'check_extension_eventids' description
# The 'check_extension_eventids' function is used with two Darwin Core files at a time - One file needs to be an 'event_core' while the other needs to be either an 'occurence_extension' or an 'extended_measurement_or_fact_extension' (event or occurrence in the latter case). The function reports if all eventIDs in an extension file have corresponding eventIDs in the core file
#
# ##### Function 'check_extension_eventids' arguments
# + event: Dataframe of the 'event_core' file to evaluate
# + extension: Dataframe of the 'extended_measurement_or_fact_extension' to evaluate
# + field (default = 'eventID'): The 'eventID' field name in the 'extended_measurement_or_fact_extension' file.
#
# ##### Relation to obistools package in R:
# They are the python equivalent of check_eventids() and check_extension_eventids()
# See documentation https://github.com/iobis/obistools#check-eventid-and-parenteventid

# %% [markdown]
# Load different types of DWC files:

# %%
event_core = pd.read_csv('https://catalogue.preprod.ogsl.ca/data/mun/ca-cioos_d006cd88-6d08-409a-9c11-2ca63a20ca1b/event_placentia_diadromous-fish.csv')
event_core.head(3)
# Out:
#                eventID   eventDate       waterBody cardinal_direction  \
# 0  MUN-EF-1-1-2020-001  2020-07-07  Plancentia Bay               east
# 1  MUN-EF-1-3-2020-002  2020-08-05  Plancentia Bay               east
# 2  MUN-EF-1-2-2020-003  2020-07-10  Plancentia Bay               east
#
#   decimalLatitude decimalLongitude  distance_ocean_m              locality  \
# 0      47,2713249      -53,8442982               200  North-east Placentia
# 1        47,16323        -53,50182               970  North-east Placentia
# 2      47,2732485      -53,8394947               650  North-east Placentia
#
#    site_number  station_number  ...  p1_starting_time  p1_ending_time  \
# 0            1               1  ...               945            1120
# 1            1               3  ...               800             920
# 2            1               2  ...               925            1045
#
#    p2_starting_volts  p2_ending_volts  p2_starting_time  p2_ending_time  \
# 0                425              445              1210            1305
# 1                545              545               950            1125
# 2                525              525              1055            1200
#
#    p3_starting_volts  p3_ending_volts  p3_starting_time  p3_ending_time
# 0                NaN              NaN               NaN             NaN
# 1                NaN              NaN               NaN             NaN
# 2                NaN              NaN               NaN             NaN
#
# [3 rows x 22 columns]

# %% [markdown]
# #### ONC Event Core Example

# %%
event_core = pd.read_csv('Z:\Desktop\obis-diveid-5040\obis-diveid-5040_0vote0pp\event.csv')
event_core.head(10)
# Out:
#    eventID parentEventID                               eventRemarks  \
# 0     1120           NaN  Cruise NEPTUNE/VENUS Maintenance 2021-03
# 1     5040          1120                  Dive OE0253 Saanich Inlet
# 2  7350290          5040                                        NaN
# 3  7350320          5040                                        NaN
# 4  7350380          5040                                        NaN
# 5  7350400          5040                                        NaN
# 6  7350410          5040                                        NaN
# 7  7350450          5040                                        NaN
# 8  7350520          5040                                        NaN
# 9  7350550          5040                                        NaN
#
#                                    eventDate              modified   type  \
# 0  2021-03-18T00:00:00Z/2021-03-30T00:00:00Z  2021-11-10T23:55:57Z  Event
# 1  2021-03-29T14:25:00Z/2021-03-29T19:47:48Z  2021-11-10T23:56:11Z  Event
# 2                       2021-03-29T14:33:50Z  2021-05-28T21:29:38Z   Text
# 3                       2021-03-29T14:37:27Z  2021-05-28T22:04:15Z   Text
# 4                       2021-03-29T14:48:04Z  2021-05-28T22:05:03Z   Text
# 5                       2021-03-29T14:48:07Z  2022-02-24T19:20:00Z   Text
# 6                       2021-03-29T14:48:55Z  2022-02-24T22:06:17Z   Text
# 7                       2021-03-29T14:51:57Z  2021-05-28T22:09:55Z   Text
# 8                       2021-03-29T14:59:30Z  2021-05-28T22:11:00Z   Text
# 9                       2021-03-29T15:05:10Z  2021-05-28T22:11:40Z   Text
#
#    habitat  decimalLatitude  decimalLongitude  minimumDepthInMeters  \
# 0      NaN              NaN               NaN                   NaN
# 1      NaN        48.653529       -123.484401                   NaN
# 2      NaN        48.650686       -123.487217                 101.0
# 3      NaN        48.650866       -123.486683                 100.0
# 4      NaN        48.650905       -123.486683                 100.0
# 5      NaN        48.650904       -123.486683                 100.0
# 6      NaN        48.650904       -123.486684                 100.0
# 7      NaN        48.650899       -123.486686                 100.0
# 8      NaN        48.650896       -123.486687                 100.0
# 9      NaN        48.650894       -123.486687                 100.0
#
#    maximumDepthInMeters verbatimCoordinateSystem geodeticDatum  \
# 0                   NaN               EPSG:26910         WGS84
# 1                   NaN               EPSG:26910         WGS84
# 2                 101.0               EPSG:26910         WGS84
# 3                 100.0               EPSG:26910         WGS84
# 4                 100.0               EPSG:26910         WGS84
# 5                 100.0               EPSG:26910         WGS84
# 6                 100.0               EPSG:26910         WGS84
# 7                 100.0               EPSG:26910         WGS84
# 8                 100.0               EPSG:26910         WGS84
# 9                 100.0               EPSG:26910         WGS84
#
#                                                                                                                                           footprintWKT
# 0                                                                                                                                                  NaN
# 1  POLYGON((-123.4944416666667 48.65638883333333, -123.4743601666667 48.65638883333333, -123.4944416666667 48.6506685, -123.4743601666667 48.6506685))
# 2                                                                                                                                                  NaN
# 3                                                                                                                                                  NaN
# 4                                                                                                                                                  NaN
# 5                                                                                                                                                  NaN
# 6                                                                                                                                                  NaN
# 7                                                                                                                                                  NaN
# 8                                                                                                                                                  NaN
# 9                                                                                                                                                  NaN

# %%
emof1 = pd.read_csv('https://catalogue.preprod.ogsl.ca/data/mun/ca-cioos_d006cd88-6d08-409a-9c11-2ca63a20ca1b/event_emof_placentia_diadromous-fish.csv')
emof1.head(3)
# Out:
#                 eventID  site_number  station_number  habitat_number  \
# 0  MUN-EF-10-1-2020-022           10               1               1
# 1  MUN-EF-10-1-2020-022           10               1               1
# 2  MUN-EF-10-1-2020-022           10               1               1
#
#         habitatID               measurementID measurementType  \
# 0  habitat-10-1-1  MUN-2020-habitat-10-1-1-01    Habitat type
# 1  habitat-10-1-1  MUN-2020-habitat-10-1-1-02  Habitat length
# 2  habitat-10-1-1  MUN-2020-habitat-10-1-1-03   Habitat width
#
#   measurementValue measurementUnit
# 0           riffle             NaN
# 1             4,81               m
# 2             23,2               m

# %% [markdown]
# Try the check_eventids function:

# %%
check_eventids(event_core)
# Out:
# Empty DataFrame
# Columns: [field, level, row, message]
# Index: []

# %% [markdown]
# Try the check_extension_eventids function:

# %%
check_extension_eventids(event_core, emof1, field = 'eventID').head()
# Out:
#         field  level   row  \
# 1461  eventid  error  1461
# 1462  eventid  error  1462
# 1463  eventid  error  1463
# 1464  eventid  error  1464
# 1465  eventid  error  1465
#
#                                                                  message
# 1461  Field MUN-EF-7-2-2020-019 has no corresponding eventID in the core
# 1462  Field MUN-EF-7-2-2020-019 has no corresponding eventID in the core
# 1463  Field MUN-EF-7-2-2020-019 has no corresponding eventID in the core
# 1464  Field MUN-EF-7-2-2020-019 has no corresponding eventID in the core
# 1465  Field MUN-EF-7-2-2020-019 has no corresponding eventID in the core
