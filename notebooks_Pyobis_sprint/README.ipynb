# %% [markdown]
# # pyobistools: Tools for data enhancement and quality control - for python!

# %% [markdown]
# ## Installation
# ---
# Installing `pyobistools` requires going to https://github.com/cioos-siooc/pyobistools/

# %%
import sys
import pandas as pd
import numpy as np
from ckanapi import RemoteCKAN
NaN = np.nan
from pyobistools.taxa import *
from pyobistools.validation.check_fields import check_fields
from pyobistools.validation.check_eventids import *
from pyobistools.validation.check_onland import *
from pyobistools.validation.check_scientificname_and_ids import *
import plotly.express as px
import requests
pd.set_option('max_colwidth', None)

# %% [markdown]
# You can also install `pyobis` - instructions: https://github.com/iobis/pyobis/blob/main/README.md

# %%
from pyobis import dataset
from pyobis import occurrences

# %% [markdown]
# ## Taxon matching
# ---
# `search_worms()` searches for records based on a list of scientific names and returns a standardized pandas DataFrame representing the results

# %%
names = ["Abra alva", "Buccinum fusiforme", "Buccinum fusiforme", "Buccinum fusiforme", "hlqsdkf"]
search_worms(names)
# Out:
#                                                               url  \
# 0  https://www.marinespecies.org/aphia.php?p=taxdetails&id=141433
# 1  https://www.marinespecies.org/aphia.php?p=taxdetails&id=531014
# 2  https://www.marinespecies.org/aphia.php?p=taxdetails&id=510389
# 3  https://www.marinespecies.org/aphia.php?p=taxdetails&id=531014
# 4  https://www.marinespecies.org/aphia.php?p=taxdetails&id=510389
# 5  https://www.marinespecies.org/aphia.php?p=taxdetails&id=531014
# 6  https://www.marinespecies.org/aphia.php?p=taxdetails&id=510389
# 7
#
#        scientificname        authority      status  \
# 0           Abra alba  (W. Wood, 1802)    accepted
# 1  Buccinum fusiforme     Kiener, 1834  unaccepted
# 2  Buccinum fusiforme   Broderip, 1830  unaccepted
# 3  Buccinum fusiforme     Kiener, 1834  unaccepted
# 4  Buccinum fusiforme   Broderip, 1830  unaccepted
# 5  Buccinum fusiforme     Kiener, 1834  unaccepted
# 6  Buccinum fusiforme   Broderip, 1830  unaccepted
# 7
#
#                                                                                                      unacceptreason  \
# 0                                                                                                              None
# 1  Invalid: junior homonym of <i>Buccinum fusiforme</i> Borson, 1820; <i>Buccinum kieneri</i> is a replacement name
# 2                                                 invalid: junior homonym of <i>Buccinum fusiforme</i> Borson, 1822
# 3  Invalid: junior homonym of <i>Buccinum fusiforme</i> Borson, 1820; <i>Buccinum kieneri</i> is a replacement name
# 4                                                 invalid: junior homonym of <i>Buccinum fusiforme</i> Borson, 1822
# 5  Invalid: junior homonym of <i>Buccinum fusiforme</i> Borson, 1820; <i>Buccinum kieneri</i> is a replacement name
# 6                                                 invalid: junior homonym of <i>Buccinum fusiforme</i> Borson, 1822
# 7
#
#       rank               valid_name    valid_authority   kingdom    phylum  \
# 0  Species                Abra alba    (W. Wood, 1802)  Animalia  Mollusca
# 1  Species  Buccinum humphreysianum      Bennett, 1824  Animalia  Mollusca
# 2  Species   Turrisipho fenestratus  (W. Turton, 1834)  Animalia  Mollusca
# 3  Species  Buccinum humphreysianum      Bennett, 1824  Animalia  Mollusca
# 4  Species   Turrisipho fenestratus  (W. Turton, 1834)  Animalia  Mollusca
# 5  Species  Buccinum humphreysianum      Bennett, 1824  Animalia  Mollusca
# 6  Species   Turrisipho fenestratus  (W. Turton, 1834)  Animalia  Mollusca
# 7
#
#    ... taxon_rank_id is_extinct parent_name_usage_id is_fresh_water  \
# 0  ...         220.0      False             138474.0          False
# 1  ...         220.0      False             137701.0          False
# 2  ...         220.0      False             137701.0          False
# 3  ...         220.0      False             137701.0          False
# 4  ...         220.0      False             137701.0          False
# 5  ...         220.0      False             137701.0          False
# 6  ...         220.0      False             137701.0          False
# 7  ...           NaN      False                  NaN          False
#
#   is_terrestrial is_marine is_brackish         match_input  matched  \
# 0          False      True       False           Abra alva     True
# 1          False      True       False  Buccinum fusiforme     True
# 2          False      True       False  Buccinum fusiforme     True
# 3          False      True       False  Buccinum fusiforme     True
# 4          False      True       False  Buccinum fusiforme     True
# 5          False      True       False  Buccinum fusiforme     True
# 6          False      True       False  Buccinum fusiforme     True
# 7          False     False       False             hlqsdkf    False
#
#    match_from
# 0       worms
# 1       worms
# 2       worms
# 3       worms
# 4       worms
# 5       worms
# 6       worms
# 7       worms
#
# [8 rows x 30 columns]

# %% [markdown]
# ## Check required fields
# ---
# `check_fields(data, level, analysis_type, accepted_name_usage_id_check)` will check all OBIS requirements are present for a given core or extension.
# - **data** = the input data as a pandas DataFrame
# - **level** = `error` or `warning`, the difference between requirements not being met or recommendations not being met
# - **analysis_type** = `event_core`, `occurrence_core`, `occurrence_extension`, or `extended_measurement_or_fact_extension`
# - **accepted_name_usage_id_check** = `True` or `False` will filter out unaccepted scientific name ids

# %%
data = pd.DataFrame(columns = ["occurrenceID","sciientificName","locality","minimumDepthInMeters"])
data["occurrenceID"] = [1,2,3]
data["scientificName"] = ["Abra alba", "NA", "NA"]
data["locality"] = ["North Sea", "English Channel", "Flemish Banks"]
data["minimumDepthInMeters"] = [10,None,5]

check_fields(data, 'error', 'occurrence_core', 'False')
# Out:
#                field  level  row                                     message
# 1      basisofrecord  error  NaN     Required field basisofrecord is missing
# 3   scientificnameid  error  NaN  Required field scientificnameid is missing
# 4          eventdate  error  NaN         Required field eventdate is missing
# 5    decimallatitude  error  NaN   Required field decimallatitude is missing
# 6   decimallongitude  error  NaN  Required field decimallongitude is missing
# 7   occurrencestatus  error  NaN  Required field occurrencestatus is missing
# 8        countrycode  error  NaN       Required field countrycode is missing
# 9            kingdom  error  NaN           Required field kingdom is missing
# 10     geodeticdatum  error  NaN     Required field geodeticdatum is missing

# %% [markdown]
# ## Plot points on a map
# ---
# `not found`

# %% [markdown]
# ## Check on-land
# ---
# `check_onland(data, land, report, buffer, offline)` will check whether given points are over land or not.
#
# - **data** = the input data as a pandas DataFrame
# - **land** = a custom land polygon to check against. If not provided, use Natural Earth.
# - **report** = if True, errors returned instead of records
# - **buffer** = set how far inland points are still to be deemed valid
# - **offline** = if True, a local simplified shoreline is used, otherwise an OBIS webservice is used. Default is False

# %%
##query = dataset.search(scientificname = 'Mola mola')
##data = query.execute() # or query.data
##data
# Out:
# {'total': 213,
#  'results': [{'id': '2101d4c5-c20b-49c0-a44b-3d6484c4c891',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_1404',
#    'archive': 'http://ipt.env.duke.edu/archive.do?r=zd_1404',
#    'published': '2022-01-20T16:06:56.000Z',
#    'created': None,
#    'updated': '2022-07-21T12:35:11.886Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 13,
#     'Occurrence': 133369,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-179.978292 -25.86469,-179.978292 51.571235,179.986607 51.571235,179.986607 -25.86469,-179.978292 -25.86469))',
#    'title': 'Observatoire Pelagis aerial surveys 2002-2021',
#    'citation': 'Van Canneyt, O. 2022. Observatoire Pelagis aerial surveys 2002-2021. Data downloaded from OBIS-SEAMAP (http://seamap.env.duke.edu/dataset/1404) on yyyy-mm-dd.',
#    'citation_id': None,
#    'abstract': "Original provider:\nObservatoire PELAGIS UAR 3462 University La Rochelle - CNRS\n\nDataset credits:\nObservatoire PELAGIS UMS 3462, University La Rochelle - CNRS -Agence des Aires Marines Protégées - Direction de l'Eau et de la Biodiversité\n\nAbstract:\nIn order to establish a baseline map of cetaceans and other pelagic megafauna across the French EEZ, the French agency for marine protected areas (AAMP) decided to conduct a series of surveys allowing hotspots of abundance and diversity to be identified and a future monitoring scheme to be established. A dedicated aerial survey methodology, following standard protocols, was preferred to ship surveys. The general design corresponds to published protocols prepared for small cetaceans, but data for other marine mammals (large whales, sirenians), seabirds, sea-turtles, large teleosts and large elasmobranchs) are collected as well. Data collected include species, group size, angle to survey track for cetaceans located within 500m on both sides of survey track, allowing line transect data analyses. For seabirds all encounters located within 200m on both sides of survey track are recorded for strip-transect analysis. Covariates collected on board include sea-state, turbidity, glare and cloud coverage. The study areas include all sectors of the French EEZ: North-East Atlantic, the tropical Atlantic (French Caribbean and Guiana), Indian (Reunion Island, Mayotte and the Scattered Islands) and south Pacific oceans (French Polynesia, New Caledonia, Wallis and Futuna). \nThese surveys follow the general SCANS methodology (Hiby and Lovell, 1998) adapted to aircrafts. A zigzag track layout is used and transects are sampled at a target altitude of 180 m and ground speed of 90 nm.h-1 (167 km.h-1). Survey platforms are high-wing, double-engine aircrafts fitted with bubble windows; a Partenavia P68 was used in 2008 in the Atlantic and two Britten Norman BN-2 in 2009-10 in the southwest Indian Ocean. \nSurvey crew typically consists in two trained observers observing with naked eyes and a flight leader in charge of data collection.\n\nPurpose:\nIn order to establish a baseline map of cetaceans and other pelagic megafauna across the French EEZ, it was decided to conduct a series of surveys from 2008 onwards following a standardized methodology that would allow comparisons within and between regions as well as temporally, for the sake of the identification of hotspots of abundance and diversity and the establishment of a future monitoring scheme. These surveys are named the REMMOA and SAMM surveys for REcensement des Mammifères marins et autre Mégafaune pélagique par Observation Aérienne (Census of marine mammals and other pelagic megafauna by aerial survey) and Suivi Aérien de la Megafaune Marine (Aerial survey for marine megafauna). Additionally, considering the fragmented nature of the French EEZ, notably compared to the spatial scale that is relevant for the species of interest, the implementation of these surveys at regional scale by collaboration with neighboring countries was encouraged.\n\nSupplemental information:\n[2022-01-18] Data in 2020 were appended.\n[2018-04-26] Data in 2016 and 2017 were appended.\n\nTime and group size of the sightings are not available online. They may be released upon request.\n\nThere are records for plankton observations but these records are not visible online.\n\nThe animals the provider identified as Sterninae spp were registered as Laridae spp. However, you can still see the original species identification online.",
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': None,
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'Olivier',
#      'surname': 'Van Canneyt',
#      'organization': 'Observatoire Pelagis UMS 3462, University La Rochelle - CNRS',
#      'position': 'Primary contact',
#      'email': 'olivier.van-canneyt@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Hélène',
#      'surname': 'Peltier',
#      'organization': 'Observatoire PELAGIS, UMS 3462, University La Rochelle-CNRS',
#      'position': 'Secondary contact',
#      'email': 'hpeltier@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Olivier',
#      'surname': 'Van Canneyt',
#      'organization': 'Observatoire Pelagis UMS 3462, University La Rochelle - CNRS',
#      'position': 'Primary contact',
#      'email': 'olivier.van-canneyt@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'https://seamap.env.duke.edu',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'https://seamap.env.duke.edu',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'Olivier',
#      'surname': 'Van Canneyt',
#      'organization': 'Observatoire Pelagis UMS 3462, University La Rochelle - CNRS',
#      'position': 'Primary contact',
#      'email': 'olivier.van-canneyt@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'associatedParty',
#      'givenname': 'Hélène',
#      'surname': 'Peltier',
#      'organization': 'Observatoire PELAGIS, UMS 3462, University La Rochelle-CNRS',
#      'position': 'Secondary contact',
#      'email': 'hpeltier@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'Olivier',
#      'surname': 'Van Canneyt',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'personnel',
#      'givenname': 'Hélène',
#      'surname': 'Peltier',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,Marine Animal Survey,Marine Biology,Seabirds,Marine mammals,Sea turtles,Elasmobranchii,Visual Sighting,Aircraft',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 6607, 'records': 218245196},
#     {'year': 2021, 'downloads': 5941, 'records': 245952761},
#     {'year': 2020, 'downloads': 1937, 'records': 80901208},
#     {'year': 2019, 'downloads': 541, 'records': 7064283},
#     {'year': 2018, 'downloads': 4, 'records': 14872}],
#    'records': 3781},
#   {'id': 'ea93b52d-23aa-4be7-9686-a56be3b3ee2b',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_513',
#    'archive': 'https://ipt.env.duke.edu/archive.do?r=zd_513',
#    'published': '2022-08-31T19:53:20.000Z',
#    'created': None,
#    'updated': '2022-08-31T20:18:01.199Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 0,
#     'Occurrence': 47310,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-75.44653 37.20013,-75.44653 50.15105,-58.0944 50.15105,-58.0944 37.20013,-75.44653 37.20013))',
#    'title': 'NEFSC Right Whale Aerial Survey',
#    'citation': 'Cole, T. and C. Khan. 2022. NEFSC Right Whale Aerial Survey. Data downloaded from OBIS-SEAMAP (http://seamap.env.duke.edu/dataset/513) on yyyy-mm-dd.',
#    'citation_id': 'https://seamap.env.duke.edu/dataset/513',
#    'abstract': 'Original provider:\nNOAA Northeast Fisheries Science Center (NEFSC)\n\nDataset credits:\nProtected Species Branch, Northeast Fisheries Science Center, NOAA/NMFS\n\nAbstract:\nThe North Atlantic Right Whale Sighting Survey (NARWSS) is a NOAA Fisheries program which locates and records the seasonal distribution of right whales off the northeastern United States.\n\nPurpose:\nnot provided\n\nSupplemental information:\n2022-08-31: The 2022 data were appended.\n2022-02-03: The 2021 data were appended.\n2021-06-22: The 2020 data were appended.\n2020-12-30: The 2018-19 data were appended.\n2019-10-30: The date/time of the 2017 data were corrected (initially they were at UTC. Now they are at local time zone as other records are).\n2019-09-13: The 2017 data were appended.\n2017-03-10: Data format was changed and the 2016 data were appended.\n2016-06-09: 2015 Nov-Dec data were appended.\n2016-03-08: 2015 Jan-Aug data were appended.\nThe following two records got the animal count corrected.\n- Right whale 06/03/02 16:58:20 0 -&gt; 3\n- Basking shark 06/20/03 17:52:03 0 =&gt; 1 (dead shark)\n2015-05-06: 2013 winter and 2014 data were appended.\n2015-03-24: A few records had a wrong animal count of zero. The value is replaced with a blank representing species presence only.\n2014-08-11: Sightings originally identified as \'CWDO\' and not included in the dataset were reclassified as \'UNCW\' (common or white-sided dolphin) and now are included.\n2014-02-27: Data in 2013 Jan through July were appended.\n2013-12-18: The count field for the following two records were updated:\nRight whale 2002-06-03 16:58:20: Null (previously a zero)\nBasking shark 2003-06-20 17:52:03: 1 (previously a zero)\n2013-03-04: Upon provider\'s request, right whale sightings with all psb_legstage flags except \'9\' were dropped to avoid potential re-sightings to be mapped.\npsb_legstage, a hidden attribute, is a flag indicating the stage of watch. The value of \'9\' indicates a final estimate of right whales after the animals were first sighted.\n2013-01-22: 2012 data were appended.\nData format for the 2007-2011 data was changed from the Consortium format to the NEFSC original format.\n2012-09-24: The dataset name was changed from NEFSC Right Whale Survey to NEFSC Right Whale Aerial Survey to distinguish this from the associated vessel survey.\n2012-06-25: Data correction: STDO was classified as Stenella coeruleoalba (previously as Stenella attenuata/frontalis). \n2012-06-20: 2011 data were added. \nData correction 2/8/11: Records with LETU sightings were incorrectly associated with Softshell turtles (ITIS TSN: 173845) and was corrected as leatherback sea turtles (ITIS TSN: 173843)\n\nOther references:\n<a href="http://www.nefsc.noaa.gov/publications/crd/crd0905/">Khan C, Cole TVN, Duley P, Glass AH, Niemeyer M, Christman C. 2009. North Atlantic Right Whale Sighting Survey (NARWSS) and Right Whale Sighting Advisory System (RWSAS) 2008 Results Summary. US Dept Commer, Northeast Fish Sci Cent Ref Doc. 09-05; 7 p.</a>\n\n<a href="http://www.nefsc.noaa.gov/publications/crd/crd0806/index.html">Niemeyer, M., T.V.N. Cole, C.L. Christman, P. Duley and A.H. Glass. 2008. North Atlantic Right Whale Sighting Survey (NARWSS) and Right Whale Sighting Advisory System (RWSAS) 2007 results summary. Northeast Fisheries Science Center Reference Document. 08-06; 6 p. </a>\n\n<a href="http://www.nefsc.noaa.gov/publications/crd/crd0702/">Cole TVN, Gerrior P, Merrick RL. 2007. Methodologies of the NOAA National Marine Fisheries Service aerial survey program for right whales (Eubalaena glacialis) in the Northeast U.S., 1998-2006. US Dep Commer, Northeast Fish Sci Cent Ref Doc 07-02; 11 p.</a>',
#    'intellectualrights': 'To the extent possible under law, the publisher has waived all rights to these data and has dedicated them to the  Public Domain (CC0 1.0)',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': None,
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'Tim',
#      'surname': 'Cole',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Primary contact',
#      'email': 'Tim.Cole@noaa.gov',
#      'url': 'http://www.nefsc.noaa.gov/psb/surveys/',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Christin',
#      'surname': 'Khan',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Secondary contact',
#      'email': 'Christin.Khan@noaa.gov',
#      'url': 'http://www.cbkhan.com',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Alison',
#      'surname': 'Ogilvie',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Secondary contact',
#      'email': 'alison.ogilvie@noaa.gov',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Tim',
#      'surname': 'Cole',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Primary contact',
#      'email': 'Tim.Cole@noaa.gov',
#      'url': 'http://www.nefsc.noaa.gov/psb/surveys/',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'https://seamap.env.duke.edu',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'https://seamap.env.duke.edu',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'Tim',
#      'surname': 'Cole',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Primary contact',
#      'email': 'Tim.Cole@noaa.gov',
#      'url': 'http://www.nefsc.noaa.gov/psb/surveys/',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'associatedParty',
#      'givenname': 'Christin',
#      'surname': 'Khan',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Secondary contact',
#      'email': 'Christin.Khan@noaa.gov',
#      'url': 'www.cbkhan.com',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'originator',
#      'type': 'associatedParty',
#      'givenname': 'Alison',
#      'surname': 'Ogilvie',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Secondary contact',
#      'email': 'alison.ogilvie@noaa.gov',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'Tim',
#      'surname': 'Cole',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'personnel',
#      'givenname': 'Christin',
#      'surname': 'Khan',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'originator',
#      'type': 'personnel',
#      'givenname': 'Alison',
#      'surname': 'Ogilvie',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,Marine Animal Survey,Marine Biology,Marine mammals,Aircraft,Visual Sighting',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 4772, 'records': 78953922},
#     {'year': 2021, 'downloads': 5201, 'records': 88977959},
#     {'year': 2020, 'downloads': 2751, 'records': 29699505},
#     {'year': 2019, 'downloads': 470, 'records': 4535464},
#     {'year': 2018, 'downloads': 2, 'records': 44793}],
#    'records': 3095},
#   {'id': '9a81d405-545b-4a1b-bdaa-aff5350a0c39',
#    'url': 'http://ipt.vliz.be/eurobis/resource?r=gbif_14998',
#    'archive': 'https://ipt.vliz.be/eurobis/archive.do?r=gbif_14998',
#    'published': '2022-12-09T11:17:43.000Z',
#    'created': None,
#    'updated': '2022-12-09T16:35:44.475Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 1,
#     'Occurrence': 16568,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-9.62795 40.12121,-9.62795 51.4855,10.1635 51.4855,10.1635 40.12121,-9.62795 40.12121))',
#    'title': 'National Inventory of the Natural Heritage: Data from the air monitoring campaigns of marine megafauna (SAMM) in the French metropolitan area',
#    'citation': "SPN - Service du Patrimoine naturel, Muséum national d'Histoire naturelle, Paris: Inventaire National du Patrimoine Naturel : Données des campagnes de Suivi Aérien de la Mégafaune Marine (SAMM) de France métropolitaine, 2013-06-20. Accessed via http://www.gbif.org/dataset/489cf485-b8de-4d38-a01a-6f426c658222 on yyyy-mm-dd https://doi.org/10.15468/dylxhs",
#    'citation_id': 'https://doi.org/10.15468/dylxhs',
#    'abstract': 'Data from air monitoring of marine megafauna in the maritime French metropolitan area and its adjacent areas.',
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution (CC-BY) 4.0 License',
#    'feed': {'id': 'e3dad797-a123-4e78-8473-5b0a295d3685',
#     'url': 'http://ipt.vliz.be/eurobis/rss.do'},
#    'institutes': None,
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': None,
#      'surname': None,
#      'organization': 'National Natural History Museum Paris; Service du Patrimoine naturel',
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Olivier',
#      'surname': 'Van Canneyt',
#      'organization': 'Université de La Rochelle; Observatoire Pelagis (UMS 3462)',
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Frédéric',
#      'surname': 'Vest',
#      'organization': 'National Natural History Museum Paris; Service du Patrimoine naturel',
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': 'Frédéric',
#      'surname': 'Vest',
#      'organization': 'National Natural History Museum Paris; Service du Patrimoine naturel',
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Metadata Provider'}],
#    'nodes': [{'id': '4bf79a01-65a9-4db6-b37b-18434f26ddfc',
#      'name': 'EurOBIS'}],
#    'keywords': [{'keyword': 'Megafauna', 'thesaurus': 'ASFA'},
#     {'keyword': 'Sharks', 'thesaurus': 'ASFA'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 3263, 'records': 27634684},
#     {'year': 2021, 'downloads': 4001, 'records': 32298782},
#     {'year': 2020, 'downloads': 1219, 'records': 10734682},
#     {'year': 2019, 'downloads': 275, 'records': 1086088},
#     {'year': 2018, 'downloads': 3, 'records': 3168}],
#    'records': 2786},
#   {'id': '6669ce88-d264-42a5-b34c-bb7f01c3952c',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_283',
#    'archive': 'http://ipt.env.duke.edu/archive.do?r=zd_283',
#    'published': '2021-04-24T09:09:58.000Z',
#    'created': None,
#    'updated': '2022-07-20T20:55:28.463Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 0,
#     'Occurrence': 11080,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-81.3 28.767,-81.3 45.033,-61.483 45.033,-61.483 28.767,-81.3 28.767))',
#    'title': 'BLM CETAP AIR Sightings',
#    'citation': 'Kenney, R. 2013. BLM CETAP AIR Sightings. Data downloaded from OBIS-SEAMAP (http://seamap.env.duke.edu/dataset/283) on yyyy-mm-dd.',
#    'citation_id': 'https://seamap.env.duke.edu/dataset/283',
#    'abstract': 'Original provider:\nUniversity of Rhode Island\n\nDataset credits:\nUniversity of Rhode Island\nBureau of Land Management\nU.S. Dept of the Interior\n\nAbstract:\nThe Cetacean and Turtle Assessment Program (CETAP) was sponsored by the Bureau of Land Management and conducted between October 1978 and January 1982 by the University of Rhode Island in outer continental shelf waters of the northeastern United States from Cape Hatteras, North Carolina, to the Gulf of Maine and from shore to 9.3 km (5 nautical miles) seaward of the 1829 m (1,000 fathoms) isobath. Population surveys were conducted by CETAP to assess the distribution and abundance of whales, dolphins and sea turtles inhabiting the study area.\n\nPurpose:\nThis dataset is a subset of CETAP_AIR extracting animal sighting records with taxonomic information of species sighted added. The full dataset may be available upon request. Please contact the primary contact person for the proper use of the dataset.\n\nSupplemental information:\n[2020-09-30] The following invalid species names were corrected according to the Integrated Taxonomic Information System (ITIS).\nTurtles: Testudines (173749) =&gt; Testudines (948936)\n\nMetadata are currently being revised. Sighting points that were more than 2 km inland were eliminated. Those from 1 km to 2 km inland can be considered as on-water sightings. Those records have TRUE in the [Excluded] field to indicate that they seem to fall on land but may be correct sightings.',
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': [{'name': 'Duke University',
#      'oceanexpert_id': 19393,
#      'oceanexpert_parent_id': None}],
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'Robert',
#      'surname': 'Kenney',
#      'organization': 'University of Rhode Island',
#      'position': 'Primary contact',
#      'email': 'rkenney@gso.uri.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Robert',
#      'surname': 'Kenney',
#      'organization': 'University of Rhode Island',
#      'position': 'Primary contact',
#      'email': 'rkenney@gso.uri.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'Robert',
#      'surname': 'Kenney',
#      'organization': 'University of Rhode Island',
#      'position': 'Primary contact',
#      'email': 'rkenney@gso.uri.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'Robert',
#      'surname': 'Kenney',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,Marine Animal Survey,Marine Biology,Marine mammals,Sea turtles,Aircraft,Visual Sighting',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 5829, 'records': 18673961},
#     {'year': 2021, 'downloads': 5997, 'records': 21547224},
#     {'year': 2020, 'downloads': 2148, 'records': 7130960},
#     {'year': 2019, 'downloads': 459, 'records': 918329},
#     {'year': 2018, 'downloads': 2, 'records': 12236}],
#    'records': 1609},
#   {'id': '924c4d25-6358-44a3-8f4d-24086256ad3e',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_1403',
#    'archive': 'https://ipt.env.duke.edu/archive.do?r=zd_1403',
#    'published': '2022-10-20T14:53:17.000Z',
#    'created': None,
#    'updated': '2022-10-20T15:32:33.539Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 1391,
#     'Occurrence': 89382,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-11.292789 -25.61275,-11.292789 55.280026,47.3583 55.280026,47.3583 -25.61275,-11.292789 -25.61275))',
#    'title': 'Observatoire Pelagis boat surveys 2003-2021',
#    'citation': 'Doremus, G. 2022. Observatoire Pelagis boat surveys 2003-2021. Data downloaded from OBIS-SEAMAP (http://seamap.env.duke.edu/dataset/1403) on yyyy-mm-dd.',
#    'citation_id': None,
#    'abstract': 'Original provider:\nObservatoire PELAGIS UAR 3462 University La Rochelle - CNRS\n\nDataset credits:\nObservatoire PELAGIS UAR 3462, University La Rochelle - CNRS\n\nAbstract:\nSince 2003, the Observatoire PELAGIS (La Rochelle University) participated to annual halieutic surveys, led by the IFREMER, to collect data on the distribution of marine top predators in order to estimate their relative abundance and preferred habitats in the Bay of Biscay, the Channel and the North Sea. \nEach year, three observers take place on board the vessel “Thalassa” to record sightings of seabirds, marine mammals, large fish and fishing boats, from dawn to dusk. Following distance sampling methods, visual censuses are made by two observers (while the third observer is resting) from the upper platform of the boat (min. 14m above the sea level). They are placed on each side of the deck, looking ahead for marine predator with an angle of 180°. For each sighting, the species and the number of individuals are recorded, as well as the behaviour, distance and angle (upon request).\n\nPurpose:\nOne of the main advantages of this survey lays in its ecosystemic approach, which provides information on all the components of the food web (from planktonic organisms to predators) as well as data on the environmental parameters (sea surface temperature, salinity…). Interactions between prey and predators are complex in marine ecosystems, which are submitted to strong spatio-temporal variations. Thanks to ecosystem-based surveys, observed distributions and densities of marine predators can be related to the occurrence of their prey, providing to scientists and managers a better understanding of the marine ecosystems structure.\n\nSupplemental information:\n[2022-10-20] The records on 2016-09-21 got the longitude sign swapped. they are corrected.\n[2022-01-18] Data in 2020 and 2021 were appended.\n[2018-04-26] Data in 2016 and 2017 were appended.\n\nTime and group size of the sightings are not available online. They may be released upon request.',
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': None,
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'Ghislain',
#      'surname': 'Doremus',
#      'organization': 'Observatoire Pelagis UMS 3462, University La Rochelle - CNRS',
#      'position': 'Primary contact',
#      'email': 'gdoremus@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Hélène',
#      'surname': 'Peltier',
#      'organization': 'Observatoire PELAGIS, UMS 3462, University La Rochelle-CNRS',
#      'position': 'Secondary contact',
#      'email': 'hpeltier@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Ghislain',
#      'surname': 'Doremus',
#      'organization': 'Observatoire Pelagis UMS 3462, University La Rochelle - CNRS',
#      'position': 'Primary contact',
#      'email': 'gdoremus@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'https://seamap.env.duke.edu',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'https://seamap.env.duke.edu',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'Ghislain',
#      'surname': 'Doremus',
#      'organization': 'Observatoire Pelagis UMS 3462, University La Rochelle - CNRS',
#      'position': 'Primary contact',
#      'email': 'gdoremus@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'associatedParty',
#      'givenname': 'Hélène',
#      'surname': 'Peltier',
#      'organization': 'Observatoire PELAGIS, UMS 3462, University La Rochelle-CNRS',
#      'position': 'Secondary contact',
#      'email': 'hpeltier@univ-lr.fr',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'Ghislain',
#      'surname': 'Doremus',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'personnel',
#      'givenname': 'Hélène',
#      'surname': 'Peltier',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,Marine Animal Survey,Marine Biology,Seabirds,Marine mammals,Cetaceans,Sea turtles,Elasmobranchii,Visual Sighting,Vessel',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 4614, 'records': 143252540},
#     {'year': 2021, 'downloads': 5605, 'records': 139678790},
#     {'year': 2020, 'downloads': 1531, 'records': 41855563},
#     {'year': 2019, 'downloads': 355, 'records': 3550445},
#     {'year': 2018, 'downloads': 3, 'records': 16345}],
#    'records': 680},
#   {'id': '9afeee64-62f3-44b9-a2fb-794b2afcf50a',
#    'url': 'http://ipt.vliz.be/eurobis/resource?r=dasshdt00000002',
#    'archive': 'https://ipt.vliz.be/eurobis/archive.do?r=dasshdt00000002',
#    'published': '2022-12-09T10:33:07.000Z',
#    'created': None,
#    'updated': '2022-12-11T12:43:45.116Z',
#    'core': 'event',
#    'extensions': ['measurementorfact', 'occurrence'],
#    'statistics': {'Event': 2072,
#     'absence': 4,
#     'dropped': 2,
#     'Occurrence': 2072,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 2002},
#    'extent': 'POLYGON((-16.866666666667 32.735413,-16.866666666667 68.911606,15.071944 68.911606,15.071944 32.735413,-16.866666666667 32.735413))',
#    'title': 'Marine fish volunteer ad-hoc recording scheme and historical records from around the United Kingdom between 1743 and 2010',
#    'citation': 'The National Marine Aquarium, United Kingdom (2019) Marine fish volunteer ad-hoc recording scheme and historical records from around the United Kingdom between 1743 and 2010 https://doi.org/10.17031/2x2hau',
#    'citation_id': 'https://doi.org/10.17031/2x2hau',
#    'abstract': '"Volunteer marine fish records from a wide variety of sources including dive sightings, fishermen\'s records, anglers etc. as well as historical records collated from other sources such as museum specimens and marine faunas from 1743 - 2010. Records are from around the United Kingdom and some further reaching locations submitted to and collected by The National Marine Aquarium, Plymouth.\n"',
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution (CC-BY) 4.0 License',
#    'feed': {'id': 'e3dad797-a123-4e78-8473-5b0a295d3685',
#     'url': 'http://ipt.vliz.be/eurobis/rss.do'},
#    'institutes': [{'name': 'Vlaams Instituut voor de Zee',
#      'oceanexpert_id': 6223,
#      'oceanexpert_parent_id': None},
#     {'name': 'The Marine Biological Association of the United Kingdom',
#      'oceanexpert_id': 7168,
#      'oceanexpert_parent_id': None}],
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': None,
#      'surname': None,
#      'organization': 'National Marine Aquarium',
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': None,
#      'surname': None,
#      'organization': 'Flanders Marine Institute (VLIZ)',
#      'position': None,
#      'email': 'info@vliz.be',
#      'url': 'https://www.vliz.be',
#      'organization_oceanexpert_id': 6223,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': 'Hannah',
#      'surname': 'Milburn',
#      'organization': 'Marine Biological Association of the UK',
#      'position': None,
#      'email': 'sec@mba.ac.uk',
#      'url': None,
#      'organization_oceanexpert_id': 7168,
#      'type_display': 'Metadata Provider'}],
#    'nodes': [{'id': '4bf79a01-65a9-4db6-b37b-18434f26ddfc', 'name': 'EurOBIS'},
#     {'id': 'f92d5d7f-47a6-4605-9fd0-a8538dfde3fd', 'name': 'OBIS UK'}],
#    'keywords': [{'keyword': 'Benthic marine fish', 'thesaurus': 'ASFA'},
#     {'keyword': 'Citizen science', 'thesaurus': 'ASFA'},
#     {'keyword': 'Data', 'thesaurus': 'ASFA'},
#     {'keyword': 'Demersal fishes', 'thesaurus': 'ASFA'},
#     {'keyword': 'diver', 'thesaurus': 'ASFA'},
#     {'keyword': 'Marine Genomics', 'thesaurus': 'ASFA'},
#     {'keyword': 'Pelagic fishes', 'thesaurus': 'ASFA'},
#     {'keyword': 'Samplingevent',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 11451, 'records': 3535863},
#     {'year': 2021, 'downloads': 14309, 'records': 4103193},
#     {'year': 2020, 'downloads': 3475, 'records': 1376111},
#     {'year': 2019, 'downloads': 406, 'records': 138141}],
#    'records': 631},
#   {'id': '47ab07e9-ac50-47b1-9ca1-421b5aafe1db',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_1997',
#    'archive': 'http://ipt.env.duke.edu/archive.do?r=zd_1997',
#    'published': '2021-04-27T18:22:20.000Z',
#    'created': '2020-04-10T23:52:05.539Z',
#    'updated': '2022-07-20T19:26:52.636Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 2,
#     'dropped': 0,
#     'Occurrence': 1667,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-73.677971 38.948364,-73.677971 44.966145,-62.737175 44.966145,-62.737175 38.948364,-73.677971 38.948364))',
#    'title': 'AMAPPS Northeast Aerial Cruise Spring 2017',
#    'citation': 'NEFSC. 2018. 2017 Annual Report of a Comprehensive Assessment of Marine Mammal, Marine Turtle, and Seabird Abundance and Spatial Distribution in US waters of the Western North Atlantic Ocean – AMAPPS II. Annual Report. Available at: https://www.fisheries.noaa.gov/resource/publication-database/atlantic-marine-assessment-program-protected-species.',
#    'citation_id': None,
#    'abstract': 'Original provider:\nNOAA Northeast Fisheries Science Center (NEFSC)\n\nDataset credits:\nNOAA Northeast Fisheries Science Center (NEFSC)\n\nAbstract:\nDuring 6 June 2017 – 15 July 2017, the Northeast Fisheries Science Center (NEFSC) conducted aerial abundance surveys targeting marine mammals and sea turtles. The southwestern extent was New Jersey and the northeastern extent was off of Halifax, Nova Scotia, Canada. This survey covered waters from the coast line to about the 2000 m depth contour with a higher coverage over the New York State Offshore Planning Area. This survey coordinated with the SE aerial survey south of this study area in US waters. Track lines were flown 183 m (600 ft) above the water surface, at about 200 kph (110 knots). The two-independent team methodology was used to collect data. In Beaufort sea states of six and less, about 9,479 km of on-effort track lines were surveyed, where 95% of this effort was in Beaufort 3 and below.\n\nPurpose:\nThe objectives of this aerial flight was to collect the data needed to estimate abundance of cetaceans and turtles in the study area and to investigate how the animals’ distribution and abundance relate to their ecosystem.\n\nSupplemental information:\nThe survey code is TONE17SPR.\n\nPerpendicular distance to the animal is not publicly available. Please contact the data provider to obtain this attribute.',
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': [{'name': 'Duke University',
#      'oceanexpert_id': 19393,
#      'oceanexpert_parent_id': None}],
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'Beth',
#      'surname': 'Josephson',
#      'organization': 'NOAA Fisheries',
#      'position': 'Primary contact',
#      'email': 'elizabeth.josephson@noaa.gov',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Debi',
#      'surname': 'Palka',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Secondary contact',
#      'email': 'dpalka@whsun1.wh.whoi.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Beth',
#      'surname': 'Josephson',
#      'organization': 'NOAA Fisheries',
#      'position': 'Primary contact',
#      'email': 'elizabeth.josephson@noaa.gov',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'Beth',
#      'surname': 'Josephson',
#      'organization': 'NOAA Fisheries',
#      'position': 'Primary contact',
#      'email': 'elizabeth.josephson@noaa.gov',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'associatedParty',
#      'givenname': 'Debi',
#      'surname': 'Palka',
#      'organization': 'NOAA Northeast Fisheries Science Center',
#      'position': 'Secondary contact',
#      'email': 'dpalka@whsun1.wh.whoi.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'Beth',
#      'surname': 'Josephson',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'personnel',
#      'givenname': 'Debi',
#      'surname': 'Palka',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,Marine Animal Survey,Marine Biology,Marine mammals,Sea turtles,Visual Sighting,Aircraft',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 3311, 'records': 2854980},
#     {'year': 2021, 'downloads': 4472, 'records': 3349457},
#     {'year': 2020, 'downloads': 1804, 'records': 1107128}],
#    'records': 587},
#   {'id': 'a646ef47-45d2-489e-9593-a5dfd2173b91',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_1817',
#    'archive': 'http://ipt.env.duke.edu/archive.do?r=zd_1817',
#    'published': '2021-04-24T07:44:47.000Z',
#    'created': None,
#    'updated': '2022-07-21T00:02:31.026Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 0,
#     'Occurrence': 54550,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-73.9195 38.4533,-73.9195 41.0759,-70.567 41.0759,-70.567 38.4533,-73.9195 38.4533))',
#    'title': 'Digital Aerial Baseline Survey of Marine Wildlife in Support of Offshore Wind Energy - OPA 2016',
#    'citation': 'APEM and Normandeau Associates prepared for New York State Energy Research and Development Authority. 2018. Digital Aerial Baseline Survey of Marine Wildlife in Support of Offshore Wind Energy - OPA 2016. Data downloaded from OBIS-SEAMAP (http://seamap.env.duke.edu/dataset/1817) on yyyy-mm-dd.',
#    'citation_id': 'https://remote.normandeau.com',
# ...
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': [{'name': 'Duke University',
#      'oceanexpert_id': 19393,
#      'oceanexpert_parent_id': None}],
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'William',
#      'surname': 'McLellan',
#      'organization': 'University of North Carolina Wilmington',
#      'position': 'Primary contact',
#      'email': 'mclellanw@uncw.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'William',
#      'surname': 'McLellan',
#      'organization': 'University of North Carolina Wilmington',
#      'position': 'Primary contact',
#      'email': 'mclellanw@uncw.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'William',
#      'surname': 'McLellan',
#      'organization': 'University of North Carolina Wilmington',
#      'position': 'Primary contact',
#      'email': 'mclellanw@uncw.edu',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'William',
#      'surname': 'McLellan',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,JAX Aerial,Marine Animal Survey,Marine Biology,Marine mammals,Sea turtles,Visual Sighting,Aircraft',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 2300, 'records': 110332},
#     {'year': 2021, 'downloads': 2036, 'records': 86651}],
#    'records': 1},
#   {'id': 'f306ca42-4493-4bec-b9c9-cf10764a81bd',
#    'url': 'http://ipt.env.duke.edu/resource?r=zd_2125',
#    'archive': 'http://ipt.env.duke.edu/archive.do?r=zd_2125',
#    'published': '2021-04-24T08:55:18.000Z',
#    'created': '2021-02-16T20:04:36.976Z',
#    'updated': '2022-07-20T18:23:48.756Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 0,
#     'Occurrence': 180,
#     'DNADerivedData': 0,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-57.00383 5.848,-57.00383 10.8515,-52.994 10.8515,-52.994 5.848,-57.00383 5.848))',
#    'title': 'Marine Fauna Observer data collected on board seismic survey vessels operating around Suriname as part of an EU-funded Marine Spatial Planning project',
#    'citation': 'Pool, M. and M. de Boer. 2020. Marine Fauna Observer data collected on board seismic survey vessels operating around Suriname as part of an EU-funded Marine Spatial Planning project. Data downloaded from OBIS-SEAMAP (http://seamap.env.duke.edu/dataset/2125) on yyyy-mm-dd.',
#    'citation_id': 'https://seamap.env.duke.edu/dataset/2125',
#    'abstract': "Original provider:\nGreen Heritage Fund of Suriname\n\nDataset credits:\nMonique Pool, Green Heritage Fund of Suriname\n\nAbstract:\nThe Marine Spatial Planning (MSP) project in Suriname was initiated in 2017. Part of this EU-funded project focussed on collecting all the information regarding marine megafauna within the region (Suriname and Guyana). As part of the MSP project we approached potential marine mammal data holders. In particular, oil and gas companies hold data collected by so-called Marine Fauna Observers (MFOs) during geophysical seismic surveys offshore. MFO's typically carry out dedicated watches from seismic surveys during times when the seismic source is active and non-active. As such they carry out systematic effort but without a detailed GPS-track. For the MSP-project we have used records which were classed as 'Definite' or 'Probable'. Where 'Definite' records were accompanied by photo; and 'Probable' records had a good description and were coming from a trusted source. Other records with an unsure identification (for example 'possible green turtle'), were upgraded to ‘Probable’ records of species-groups, e.g. 'hard-shelled turtle', 'ray species', 'shark species', 'dolphin sp'. All other records were discarded.\n\nPurpose:\nThe project aims to significantly enhance the governance and protection of marine and coastal resources of Guyana and Suriname through collaborative processes with all ocean takeholders, improved knowledge of the coastal and marine environment, enhanced capacity of key stakeholders and informed marine spatial management. Upon completion of the marine Spatial planning project, we aim to continue to add new marine megafauna records to OBIS SEAMAP.\n\nSupplemental information:\nAccuracy of time varies record by record. '00:00' indicates the time is not available.",
#    'intellectualrights': 'This work is licensed under a  Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License',
#    'feed': {'id': '18954703-9b9d-4584-b46d-87846532c5ee',
#     'url': 'https://ipt.env.duke.edu/rss.do'},
#    'institutes': [{'name': 'Duke University',
#      'oceanexpert_id': 19393,
#      'oceanexpert_parent_id': None}],
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': 'Monique',
#      'surname': 'Pool',
#      'organization': 'Green Heritage Fund of Suriname',
#      'position': 'Primary contact',
#      'email': 'monique@greenfundsuriname.org',
#      'url': 'https://greenfundsuriname.org/',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'creator',
#      'givenname': 'Marijke',
#      'surname': 'de Boer',
#      'organization': 'Wageningen Marine Research, University of Wageningen',
#      'position': 'Secondary contact',
#      'email': 'marijkedeboer@hotmail.com',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': 'Monique',
#      'surname': 'Pool',
#      'organization': 'Green Heritage Fund of Suriname',
#      'position': 'Primary contact',
#      'email': 'monique@greenfundsuriname.org',
#      'url': 'https://greenfundsuriname.org/',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Metadata Provider'},
#     {'role': 'distributor',
#      'type': 'associatedParty',
#      'givenname': None,
#      'surname': 'OBIS-SEAMAP',
#      'organization': 'Marine Geospatial Ecology Lab, Duke University',
#      'position': None,
#      'email': 'seamap-contact@duke.edu',
#      'url': 'http://seamap.env.duke.edu',
#      'organization_oceanexpert_id': 19393,
#      'type_display': 'Distributor'},
#     {'role': 'owner',
#      'type': 'associatedParty',
#      'givenname': 'Monique',
#      'surname': 'Pool',
#      'organization': 'Green Heritage Fund of Suriname',
#      'position': 'Primary contact',
#      'email': 'monique@greenfundsuriname.org',
#      'url': 'https://greenfundsuriname.org/',
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'associatedParty',
#      'givenname': 'Marijke',
#      'surname': 'de Boer',
#      'organization': 'Wageningen Marine Research, University of Wageningen',
#      'position': 'Secondary contact',
#      'email': 'marijkedeboer@hotmail.com',
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'},
#     {'role': 'owner',
#      'type': 'personnel',
#      'givenname': 'Monique',
#      'surname': 'Pool',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Owner'},
#     {'role': 'originator',
#      'type': 'personnel',
#      'givenname': 'Marijke',
#      'surname': 'de Boer',
#      'organization': None,
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': None,
#      'type_display': 'Originator'}],
#    'nodes': [{'id': '573654c1-4ce7-4ea2-b2f1-e4d42f8f9c31',
#      'name': 'OBIS-SEAMAP'}],
#    'keywords': [{'keyword': 'Occurrence,Marine Animal Survey,Marine Biology,Marine mammals,Sea turtles,Visual Sighting,Vessel',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'},
#     {'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type_2015-07-10.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 2523, 'records': 300704},
#     {'year': 2021, 'downloads': 2786, 'records': 312036}],
#    'records': 1},
#   {'id': 'ff8b7809-41bc-40ad-8160-0e33862817a0',
#    'url': 'http://ipt.obis.org/nonode/resource?r=fb9093',
#    'archive': 'http://ipt.obis.org/nonode/archive.do?r=fb9093',
#    'published': None,
#    'created': None,
#    'updated': '2021-09-23T17:13:45.897Z',
#    'core': 'occurrence',
#    'extensions': [],
#    'statistics': {'Event': 0,
#     'absence': 0,
#     'dropped': 440,
#     'Occurrence': 20333,
#     'MeasurementOrFact': 0},
#    'extent': 'POLYGON((-157.289993286 -49.3899993896,-157.289993286 43.9199981689,167.119995117 43.9199981689,167.119995117 -49.3899993896,-157.289993286 -49.3899993896))',
#    'title': 'Biodiversity Research Museum, Academia Sinica, Taiwan',
#    'citation': 'TELDAP, Biodiversity Research Museum, Academia Sinica, Taiwan (accessed through GBIF data portal, http://data.gbif.org/datasets/resource/9093, yyyy-mm-dd)',
#    'citation_id': None,
#    'abstract': 'This dataset contains information on specimens in the Biodiversity Research Museum, Academia Sinica, Taiwan.',
#    'intellectualrights': 'Unrestricted',
#    'feed': {'id': 'f6ecda39-1165-4b36-86d3-61ada8abd7bb',
#     'url': 'http://ipt.obis.org/nonode/rss.do'},
#    'institutes': [{'name': 'Intergovernmental Oceanographic Commission of UNESCO',
#      'oceanexpert_id': 6860,
#      'oceanexpert_parent_id': None},
#     {'name': 'Biodiversity Research Centre, Academia Sinica',
#      'oceanexpert_id': 20778,
#      'oceanexpert_parent_id': None}],
#    'contacts': [{'role': None,
#      'type': 'creator',
#      'givenname': None,
#      'surname': None,
#      'organization': 'Academia Sinica Biodiversity Research Centre',
#      'position': None,
#      'email': None,
#      'url': None,
#      'organization_oceanexpert_id': 20778,
#      'type_display': 'Creator'},
#     {'role': None,
#      'type': 'contact',
#      'givenname': None,
#      'surname': 'OBIS Secretariat',
#      'organization': 'Intergovernmental Oceanographic Commission of UNESCO',
#      'position': None,
#      'email': 'info@iobis.org',
#      'url': 'http://www.iobis.org',
#      'organization_oceanexpert_id': 6860,
#      'type_display': 'Contact'},
#     {'role': None,
#      'type': 'metadataProvider',
#      'givenname': None,
#      'surname': 'OBIS Secretariat',
#      'organization': 'Intergovernmental Oceanographic Commission of UNESCO',
#      'position': None,
#      'email': 'info@iobis.org',
#      'url': 'http://www.iobis.org',
#      'organization_oceanexpert_id': 6860,
#      'type_display': 'Metadata Provider'}],
#    'nodes': [{'id': '310922b4-9d0c-4de1-92d7-9b442d34765b',
#      'name': 'OBIS Secretariat'}],
#    'keywords': [{'keyword': 'Occurrence',
#      'thesaurus': 'GBIF Dataset Type Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_type.xml'},
#     {'keyword': 'Observation',
#      'thesaurus': 'GBIF Dataset Subtype Vocabulary: http://rs.gbif.org/vocabulary/gbif/dataset_subtype.xml'}],
#    'downloads': [{'year': 2022, 'downloads': 44111, 'records': 33064007},
#     {'year': 2021, 'downloads': 90544, 'records': 38974015},
#     {'year': 2020, 'downloads': 17603, 'records': 13335823},
#     {'year': 2019, 'downloads': 634, 'records': 1181843},
#     {'year': 2018, 'downloads': 8, 'records': 19738}],
#    'records': 1}]}

# %%
## Grab Mola mola occurrences from OBIS web server
data = occurrences.search(scientificname = 'Mola mola').execute()
# Out:
# Fetching: [████████████████████████████████████████████████████████████████████████████████████████████████████] 21360/21360
# Fetched 21360 records.

# %%
data.head(2) # shows an example of the data package
# Out:
#      infraphylum  date_year                           scientificNameID  \
# 0  Gnathostomata     2007.0  urn:lsid:marinespecies.org:taxname:127405
# 1  Gnathostomata     2019.0  urn:lsid:marinespecies.org:taxname:127405
#
#   scientificName individualCount  \
# 0      Mola mola               1
# 1      Mola mola             NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              associatedReferences  \
# 0                                                                                                                                                                                                                                                                                                                                        [{"crossref":{"citeinfo":{"origin":"Halpin, P.N., A.J. Read, E. Fujioka, B.D. Best, B. Donnelly, L.J. Hazen, C. Kot, K. Urian, E. LaBrecque, A. Dimatteo, J. Cleary, C. Good, L.B. Crowder, and K.D. Hyrenbach","pubdate":"2009","title_html":"OBIS-SEAMAP: The world data center for marine mammal, sea bird, and sea turtle distributions","title":"OBIS-SEAMAP: The world data center for marine mammal, sea bird, and sea turtle distributions","serinfo":{"sername":"Oceanography","issue":"22(2):104-115"},"onlink":"http:\/\/www.tos.org\/oceanography\/article\/obis-seamap-the-world-data-center-for-marine-mammal-sea-bird-and-sea-turtle"}}}]
# 1  [{"crossref":{"citeinfo":{"origin":"APEM and Normandeau Associates prepared for the Bureau of Ocean Energy Management (BOEM)","pubdate":"2021","title_html":"Ecological Baseline Studies of the U.S. Outer Continental Shelf Option Year 2","title":"Ecological Baseline Studies of the U.S. Outer Continental Shelf Option Year 2"}}},{"crossref":{"citeinfo":{"origin":"Halpin, P.N., A.J. Read, E. Fujioka, B.D. Best, B. Donnelly, L.J. Hazen, C. Kot, K. Urian, E. LaBrecque, A. Dimatteo, J. Cleary, C. Good, L.B. Crowder, and K.D. Hyrenbach","pubdate":"2009","title_html":"OBIS-SEAMAP: The world data center for marine mammal, sea bird, and sea turtle distributions","title":"OBIS-SEAMAP: The world data center for marine mammal, sea bird, and sea turtle distributions","serinfo":{"sername":"Oceanography","issue":"22(2):104-115"},"onlink":"http:\/\/www.tos.org\/oceanography\/article\/obis-seamap-the-world-data-center-for-marine-mammal-sea-bird-and-sea-turtle"}}}]
#
#    dropped  gigaclassid  aphiaID  decimalLatitude  ...  disposition  \
# 0    False        10194   127405          42.3800  ...          NaN
# 1    False        10194   127405          34.5414  ...          NaN
#
#   originalNameUsage associatedMedia  acceptedNameUsage acceptedNameUsageID  \
# 0               NaN             NaN                NaN                 NaN
# 1               NaN             NaN                NaN                 NaN
#
#    identificationID  verbatimSRS previousIdentifications dataGeneralizations  \
# 0               NaN          NaN                     NaN                 NaN
# 1               NaN          NaN                     NaN                 NaN
#
#                      geometry
# 0  POINT (-65.37000 42.38000)
# 1  POINT (-77.15940 34.54140)
#
# [2 rows x 159 columns]

# %%
## Passes OBIS data through a check to see whether any values may be on land or not
check_onland(data) # potentially 235 observations that might be on land
# Out:
# C:\Users\stippett\Anaconda3\envs\pyobistools\Lib\site-packages\geopandas\array.py:275: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
# C:\Users\stippett\Anaconda3\envs\pyobistools\Lib\site-packages\geopandas\geodataframe.py:1322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\stippett\Anaconda3\envs\pyobistools\Lib\site-packages\geopandas\geodataframe.py:1322: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super(GeoDataFrame, self).__setitem__(key, value)
#          infraphylum  date_year                           scientificNameID  \
# 212    Gnathostomata     2002.0  urn:lsid:marinespecies.org:taxname:127405
# 291    Gnathostomata     1990.0  urn:lsid:marinespecies.org:taxname:127405
# 382    Gnathostomata     1959.0                                        NaN
# 433    Gnathostomata     2010.0  urn:lsid:marinespecies.org:taxname:127405
# 1007   Gnathostomata     2001.0  urn:lsid:marinespecies.org:taxname:127405
# ...              ...        ...                                        ...
# 21173  Gnathostomata     2001.0  urn:lsid:marinespecies.org:taxname:127405
# 21251  Gnathostomata     2003.0  urn:lsid:marinespecies.org:taxname:127405
# 21287  Gnathostomata     1959.0  urn:lsid:marinespecies.org:taxname:127405
# 21338  Gnathostomata     1968.0  urn:lsid:marinespecies.org:taxname:127405
# 21359  Gnathostomata     2013.0  urn:lsid:marinespecies.org:taxname:127405
#
#       scientificName individualCount associatedReferences  dropped  \
# 212        Mola mola               1                  NaN    False
# 291        Mola mola             NaN                  NaN    False
# 382        Mola mola               1                  NaN    False
# 433        Mola mola             NaN                  NaN    False
# 1007       Mola mola             NaN                  NaN    False
# ...              ...             ...                  ...      ...
# 21173      Mola mola             NaN                  NaN    False
# 21251      Mola mola             NaN                  NaN    False
# 21287      Mola mola               1                  NaN    False
# 21338      Mola mola             NaN                  NaN    False
# 21359      Mola mola             NaN                  NaN    False
#
#        gigaclassid  aphiaID  decimalLatitude  ...  originalNameUsage  \
# 212          10194   127405        33.380000  ...                NaN
# 291          10194   127405        50.100000  ...                NaN
# 382          10194   127405        37.635168  ...                NaN
# 433          10194   127405        51.886170  ...                NaN
# 1007         10194   127405        51.735901  ...                NaN
# ...            ...      ...              ...  ...                ...
# 21173        10194   127405        51.166000  ...                NaN
# 21251        10194   127405        50.219019  ...                NaN
# 21287        10194   127405        38.097839  ...                NaN
# 21338        10194   127405       -28.083330  ...                NaN
# 21359        10194   127405        28.092900  ...                NaN
#
#       associatedMedia acceptedNameUsage  acceptedNameUsageID identificationID  \
# 212               NaN               NaN                  NaN              NaN
# 291               NaN               NaN                  NaN              NaN
# 382               NaN               NaN                  NaN              NaN
# 433               NaN               NaN                  NaN              NaN
# 1007              NaN               NaN                  NaN              NaN
# ...               ...               ...                  ...              ...
# 21173             NaN               NaN                  NaN              NaN
# 21251             NaN               NaN                  NaN              NaN
# 21287             NaN               NaN                  NaN              NaN
# 21338             NaN               NaN                  NaN              NaN
# 21359             NaN               NaN                  NaN              NaN
#
#        verbatimSRS  previousIdentifications dataGeneralizations  \
# 212            NaN                      NaN                 NaN
# 291            NaN                      NaN                 NaN
# 382            NaN                      NaN                 NaN
# 433            NaN                      NaN                 NaN
# 1007           NaN                      NaN                 NaN
# ...            ...                      ...                 ...
# 21173          NaN                      NaN                 NaN
# 21251          NaN                      NaN                 NaN
# 21287          NaN                      NaN                 NaN
# 21338          NaN                      NaN                 NaN
# 21359          NaN                      NaN                 NaN
#
#                           geometry on_land
# 212    POINT (-118.42000 33.38000)    True
# 291      POINT (-5.63333 50.10000)    True
# 382    POINT (-122.49467 37.63517)    True
# 433     POINT (-10.39283 51.88617)    True
# 1007     POINT (-5.22091 51.73590)    True
# ...                            ...     ...
# 21173    POINT (-4.66903 51.16600)    True
# 21251    POINT (-5.47764 50.21902)    True
# 21287  POINT (-122.26863 38.09784)    True
# 21338  POINT (153.45000 -28.08333)    True
# 21359   POINT (-14.28810 28.09290)    True
#
# [235 rows x 160 columns]
